# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pickle
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = [13.5, 9.0]
plt.rcParams['font.size'] = 24.

# %%
data_dict = {}
for file_name in os.listdir():
    if (('run-' in file_name) and 
        ('pickle' in file_name)):
        with open(file_name, 'rb') as pickle_file:
            data_dict[file_name] = pickle.load(pickle_file)

# %%
data_dict['run-1.pickle'].keys()
# Out:
# dict_keys(['tf_seed', 'batch_size', 'W', 'num_compressed_features', 'learning_rate', 'step_numbers', 'learning_algorithm', 'time', 'num_initial_features', 'loss_function_values', 'np_seed', 'num_steps'])

# %% [markdown]
# # Plots

# %%
for i, ls in zip(range(1,7), ['--', '-', '-.', '-', ':', '-.']):
    data_pickle = 'run-' + str(i) + '.pickle'
    plt.plot(data_dict[data_pickle]['step_numbers'], 
         data_dict[data_pickle]['loss_function_values'], 
             lw = 3, ls = ls, 
             label = str(data_dict[data_pickle]['learning_rate']))

plt.title('Loss Function Curves for Various Learning Rates')
plt.xlabel('Step Number')
plt.ylabel('Loss Function')

plt.legend()

# %%
for i, ls in zip(range(7,8), ['--', '-', '-.', '-', ':']):
    data_pickle = 'run-' + str(i) + '.pickle'
    plt.plot(data_dict[data_pickle]['step_numbers'], 
         data_dict[data_pickle]['loss_function_values'], 
             lw = 3, ls = ls, 
             label = str(data_dict[data_pickle]['learning_rate']))

plt.title('Loss Function Curves for Various Learning Rates')
plt.xlabel('Step Number')
plt.ylabel('Loss Function')

plt.legend()

# %%
for i, ls in zip(range(8,9), ['--', '-', '-.', '-', ':']):
    data_pickle = 'run-' + str(i) + '.pickle'
    plt.plot(data_dict[data_pickle]['step_numbers'], 
         data_dict[data_pickle]['loss_function_values'], 
             lw = 3, ls = ls, 
             label = str(data_dict[data_pickle]['learning_rate']))

plt.title('Loss Function Curves for Various Learning Rates')
plt.xlabel('Step Number')
plt.ylabel('Loss Function')

plt.legend()

# %%
for i, ls in zip(range(9,10), ['--', '-', '-.', '-', ':']):
    data_pickle = 'run-' + str(i) + '.pickle'
    plt.plot(data_dict[data_pickle]['step_numbers'], 
         data_dict[data_pickle]['loss_function_values'], 
             lw = 3, ls = ls, 
             label = str(data_dict[data_pickle]['learning_rate']))

plt.title('Loss Function Curves for Various Learning Rates')
plt.xlabel('Step Number')
plt.ylabel('Loss Function')

plt.legend()

# %%
for i, ls in zip(range(10,11), ['--', '-', '-.', '-', ':']):
    data_pickle = 'run-' + str(i) + '.pickle'
    plt.plot(data_dict[data_pickle]['step_numbers'], 
         data_dict[data_pickle]['loss_function_values'], 
             lw = 3, ls = ls, 
             label = 'Adam')

plt.title('Loss Function Curves for Various Learning Rates')
plt.xlabel('Step Number')
plt.ylabel('Loss Function')

plt.legend()
